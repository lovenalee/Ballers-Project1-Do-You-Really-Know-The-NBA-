# %%
import pandas as pd

# %%
nba_advanced = pd.read_csv('Resources/NBA Season Data.csv')
nba_adv = nba_advanced[['Player', 'Tm', 'PER', 'BPM', 'VORP', 'WS', 'Team Mar', 'Year']]

# %%
nba_adv_clean = nba_adv.dropna(axis = 0, how = 'any')
nba_adv[nba_adv["Player"] == 'LeBron James']
# Out:
#              Player   Tm   PER   BPM  VORP    WS  Team Mar  Year
# 10572  LeBron James  CLE  18.3   1.9   3.1   5.1     -3.43  2004
# 11082  LeBron James  CLE  25.7   7.8   8.3  14.3      0.33  2005
# 11609  LeBron James  CLE  28.1   8.6   9.0  16.3      2.42  2006
# 12118  LeBron James  CLE  24.5   6.9   7.1  13.7      3.52  2007
# 12618  LeBron James  CLE  29.1  10.4   9.4  15.2     -0.65  2008
# 13137  LeBron James  CLE  31.7  12.2  11.0  20.3      9.80  2009
# 13656  LeBron James  CLE  31.1  11.8  10.4  18.5      6.82  2010
# 14162  LeBron James  MIA  27.3   8.2   7.9  15.6      7.49  2011
# 14708  LeBron James  MIA  30.7  10.2   8.8  14.5      6.26  2012
# 15229  LeBron James  MIA  31.6  10.8   9.2  19.3      7.75  2013
# 15743  LeBron James  MIA  29.3   8.4   7.6  15.9      4.73  2014
# 16311  LeBron James  CLE  25.9   7.4   5.9  10.4      4.39  2015
# 16894  LeBron James  CLE  26.8   8.3   0.6   1.2      6.50  2016

# %%
nba_adv.to_csv(r'resources\NBA_Adv.csv', index = False)
