# %%
from nba_api.stats.static import players
from nba_api.stats.static import teams 

player_dict = players.get_players()
teams = teams.get_teams()


teams_df = pd.DataFrame(teams)
teams_df = teams_df.rename(columns= {'full_name' : 'team_name'})
teams_df = teams_df.rename(columns= {'id' : 'team_id' })

player_df = pd.DataFrame(player_dict)


teams_players = teams_df[:] + player_df[:]
teams_players = teams_players.merge(teams_players)
result = pd.concat([player_df, teams_df], axis=1).reindex(player_df.index)

name_id = player_df[['id', 'full_name']]

#name_id['full_name']['Forest Able']
Forest_Able = name_id.loc[name_id['full_name']=='shawu', list]

result

# %%
# First we import the endpoint
# We will be using pandas dataframes to manipulate the data
from nba_api.stats.endpoints import playergamelog
import pandas as pd 

#Call the API endpoint passing in lebron's ID & which season 

bill_russell = playergamelog.PlayerGameLog(player_id='78049', season = 'ALL', season_type_all_star= 'Playoffs')
wilt_chamberlain = playergamelog.PlayerGameLog(player_id='76375', season = 'ALL', season_type_all_star= 'Playoffs')
oscar_robertson = playergamelog.PlayerGameLog(player_id='600015', season = 'ALL', season_type_all_star= 'Playoffs')
jerry_west = playergamelog.PlayerGameLog(player_id='78497', season = 'ALL', season_type_all_star= 'Playoffs')
kareem_abdul_jabbar = playergamelog.PlayerGameLog(player_id='76003', season = 'ALL', season_type_all_star= 'Playoffs')
magic_johnson = playergamelog.PlayerGameLog(player_id='77142', season = 'ALL', season_type_all_star= 'Playoffs')
larry_bird = playergamelog.PlayerGameLog(player_id='1449', season = 'ALL', season_type_all_star= 'Playoffs')
isaiah_thomas = playergamelog.PlayerGameLog(player_id='202738', season = 'ALL', season_type_all_star= 'Playoffs')
michael_jordan = playergamelog.PlayerGameLog(player_id='893', season = 'ALL', season_type_all_star= 'Playoffs')
scottie_pippen = playergamelog.PlayerGameLog(player_id='937', season = 'ALL', season_type_all_star= 'Playoffs')
karl_malone = playergamelog.PlayerGameLog(player_id='252', season = 'ALL', season_type_all_star= 'Playoffs')
hakeem_olajuwon = playergamelog.PlayerGameLog(player_id='165', season = 'ALL', season_type_all_star= 'Playoffs')
tim_duncan = playergamelog.PlayerGameLog(player_id='1495', season = 'ALL', season_type_all_star= 'Playoffs')
shaquille_oneal = playergamelog.PlayerGameLog(player_id='2992', season = 'ALL', season_type_all_star= 'Playoffs')
kobe_brian = playergamelog.PlayerGameLog(player_id='977', season = 'ALL', season_type_all_star= 'Playoffs')
dwyane_wade = playergamelog.PlayerGameLog(player_id='2548', season = 'ALL', season_type_all_star= 'Playoffs')
lebron_james = playergamelog.PlayerGameLog(player_id='2544', season = 'ALL', season_type_all_star= 'Playoffs')
stephen_curry = playergamelog.PlayerGameLog(player_id='201939', season = 'ALL', season_type_all_star= 'Playoffs')
kevin_durant = playergamelog.PlayerGameLog(player_id='201142', season = 'ALL', season_type_all_star= 'Playoffs')
kawhi_leonard = playergamelog.PlayerGameLog(player_id='202695', season = 'ALL', season_type_all_star= 'Playoffs')


#Converts gamelog object into a pandas dataframe
#can also convert to JSON or dictionary  
df_lebron = lebron_james.get_data_frames()

# If you want all seasons, you must import the SeasonAll parameter 
from nba_api.stats.library.parameters import SeasonAll

df_lebron = playergamelog.PlayerGameLog(player_id='2544', season = SeasonAll.all)

df = df_lebron.get_data_frames()
df

# %%
'''bill_russell = name_id.loc[name_id['full_name']=='Bill Russell', list]
wilt_chamberlain = name_id.loc[name_id['full_name']=='Wilt Chamberlain', list]
oscar_robertson = name_id.loc[name_id['full_name']=='Oscar Robertson', list]
jerry_west = name_id.loc[name_id['full_name']=='Jerry West', list]
kareem_abdul_jabbar = name_id.loc[name_id['full_name']=='Kareem Abdul-Jabbar', list]
magic_johnson = name_id.loc[name_id['full_name']=='Magic Johnson', list]
larry_bird = name_id.loc[name_id['full_name']=='Larry Bird', list]
isaiah_thomas = name_id.loc[name_id['full_name']=='Isaiah Thomas', list]
michael_jordan = name_id.loc[name_id['full_name']=='Michael Jordan', list]
scottie_pippen = name_id.loc[name_id['full_name']=='Scottie Pippen', list]
karl_malone = name_id.loc[name_id['full_name']=='Karl Malone', list]
hakeem_olajuwon = name_id.loc[name_id['full_name']=='Hakeem Olajuwon', list]
tim_duncan = name_id.loc[name_id['full_name']=='Tim Duncan', list]
shaquille_oneal = name_id.loc[name_id['full_name']=="Shaquille O'Neal", list]
kobe_bryant = name_id.loc[name_id['full_name']=='Kobe Bryant', list]
dwyane_wade = name_id.loc[name_id['full_name']=='Dwyane Wade', list]
lebron_james = name_id.loc[name_id['full_name']=='LeBron James', list]
stephen_curry = name_id.loc[name_id['full_name']=='Stephen Curry', list]
kevin_durant = name_id.loc[name_id['full_name']=='Kevin Durant', list]
kawhi_leonard = player_df.loc[player_df['full_name']=='Kawhi Leonard', list]



GOAT = [bill_russell, wilt_chamberlain, oscar_robertson, jerry_west, 
        kareem_abdul_jabbar, magic_johnson, larry_bird, isaiah_thomas,
        michael_jordan, scottie_pippen, karl_malone, hakeem_olajuwon, tim_duncan, shaquille_oneal,
        kobe_brian, dwyane_wade, lebron_james, stephen_curry, kevin_durant, kawhi_leonard]

GOAT = pd.Series(GOAT)

lebron_james'''

# %%
teams_df

# %%
# First we import the endpoint
# We will be using pandas dataframes to manipulate the data
from nba_api.stats.endpoints import playergamelog
import pandas as pd 

#Call the API endpoint passing in lebron's ID & which season 
gamelog_bron = playergamelog.PlayerGameLog(player_id='2544', season = '2018')

#Converts gamelog object into a pandas dataframe
#can also convert to JSON or dictionary  
df_bron_games_2018 = gamelog_bron.get_data_frames()

# If you want all seasons, you must import the SeasonAll parameter 
from nba_api.stats.library.parameters import SeasonAll

gamelog_bron_all = playergamelog.PlayerGameLog(player_id='2544', season = SeasonAll.all)

df_bron_games_all = gamelog_bron_all.get_data_frames()

df_bron_games_all

# %%
# First we import the endpoint
# We will be using pandas dataframes to manipulate the data
from nba_api.stats.static import players
from nba_api.stats.endpoints import playergamelog
import pandas as pd 
from nba_api.stats.library.parameters import SeasonAll
from nba_api.stats.library.parameters import PlayerIDAll

#Call the API endpoint passing in lebron's ID & which season 
gamelog_bron = playergamelog.PlayerGameLog(player_id='2544', season = 'ALL', season_type_all_star= 'Playoffs')
bill_russell = playergamelog.PlayerGameLog(player_id='78049', season = 'ALL', season_type_all_star= 'Playoffs')
wilt_chamberlain = playergamelog.PlayerGameLog(player_id='76375', season = 'ALL', season_type_all_star= 'Playoffs')
oscar_robertson = playergamelog.PlayerGameLog(player_id='600015', season = 'ALL', season_type_all_star= 'Playoffs')
jerry_west = playergamelog.PlayerGameLog(player_id='78497', season = 'ALL', season_type_all_star= 'Playoffs')
kareem_abdul_jabbar = playergamelog.PlayerGameLog(player_id='76003', season = 'ALL', season_type_all_star= 'Playoffs')
magic_johnson = playergamelog.PlayerGameLog(player_id='77142', season = 'ALL', season_type_all_star= 'Playoffs')
larry_bird = playergamelog.PlayerGameLog(player_id='1449', season = 'ALL', season_type_all_star= 'Playoffs')
isaiah_thomas = playergamelog.PlayerGameLog(player_id='202738', season = 'ALL', season_type_all_star= 'Playoffs')
michael_jordan = playergamelog.PlayerGameLog(player_id='893', season = 'ALL', season_type_all_star= 'Playoffs')
scottie_pippen = playergamelog.PlayerGameLog(player_id='937', season = 'ALL', season_type_all_star= 'Playoffs')
karl_malone = playergamelog.PlayerGameLog(player_id='252', season = 'ALL', season_type_all_star= 'Playoffs')
hakeem_olajuwon = playergamelog.PlayerGameLog(player_id='165', season = 'ALL', season_type_all_star= 'Playoffs')
tim_duncan = playergamelog.PlayerGameLog(player_id='1495', season = 'ALL', season_type_all_star= 'Playoffs')
shaquille_oneal = playergamelog.PlayerGameLog(player_id='2992', season = 'ALL', season_type_all_star= 'Playoffs')
kobe_brian = playergamelog.PlayerGameLog(player_id='977', season = 'ALL', season_type_all_star= 'Playoffs')
dwyane_wade = playergamelog.PlayerGameLog(player_id='2548', season = 'ALL', season_type_all_star= 'Playoffs')
lebron_james = playergamelog.PlayerGameLog(player_id='2544', season = 'ALL', season_type_all_star= 'Playoffs')
stephen_curry = playergamelog.PlayerGameLog(player_id='201939', season = 'ALL', season_type_all_star= 'Playoffs')
kevin_durant = playergamelog.PlayerGameLog(player_id='201142', season = 'ALL', season_type_all_star= 'Playoffs')
kawhi_leonard = playergamelog.PlayerGameLog(player_id='202695', season = 'ALL', season_type_all_star= 'Playoffs')

#Converts gamelog object into a pandas dataframe
#can also convert to JSON or dictionary  
lebron_james = lebron_james.get_data_frames()
kawhi_leonard = kawhi_leonard.get_data_frames()
scottie_pippen = scottie_pippen.get_dataframes()
# If you want all seasons, you must import the SeasonAll parameter

# %%
#df_bron_games[0]['Player_ID']
#df_bron_games_all[:]

# %%
# First we import the endpoint
# We will be using pandas dataframes to manipulate the data
from nba_api.stats.endpoints import playergamelog
import pandas as pd 

#Call the API endpoint passing in lebron's ID & which season 
gamelog_bron = playergamelog.PlayerGameLog(player_id='2544', season = '2018')

#Converts gamelog object into a pandas dataframe
#can also convert to JSON or dictionary  
df_bron_games_2018 = gamelog_bron.get_data_frames()

# If you want all seasons, you must import the SeasonAll parameter 
from nba_api.stats.library.parameters import SeasonAll

bill_russell = playergamelog.PlayerGameLog(player_id='78049', season = 'ALL', season_type_all_star= 'Playoffs')
wilt_chamberlain = playergamelog.PlayerGameLog(player_id='76375', season = 'ALL', season_type_all_star= 'Playoffs')
oscar_robertson = playergamelog.PlayerGameLog(player_id='600015', season = 'ALL', season_type_all_star= 'Playoffs')
jerry_west = playergamelog.PlayerGameLog(player_id='78497', season = 'ALL', season_type_all_star= 'Playoffs')
kareem_abdul_jabbar = playergamelog.PlayerGameLog(player_id='76003', season = 'ALL', season_type_all_star= 'Playoffs')
magic_johnson = playergamelog.PlayerGameLog(player_id='77142', season = 'ALL', season_type_all_star= 'Playoffs')
larry_bird = playergamelog.PlayerGameLog(player_id='1449', season = 'ALL', season_type_all_star= 'Playoffs')
isaiah_thomas = playergamelog.PlayerGameLog(player_id='202738', season = 'ALL', season_type_all_star= 'Playoffs')
michael_jordan = playergamelog.PlayerGameLog(player_id='893', season = 'ALL', season_type_all_star= 'Playoffs')
scottie_pippen = playergamelog.PlayerGameLog(player_id='937', season = 'ALL', season_type_all_star= 'Playoffs')
karl_malone = playergamelog.PlayerGameLog(player_id='252', season = 'ALL', season_type_all_star= 'Playoffs')
hakeem_olajuwon = playergamelog.PlayerGameLog(player_id='165', season = 'ALL', season_type_all_star= 'Playoffs')
tim_duncan = playergamelog.PlayerGameLog(player_id='1495', season = 'ALL', season_type_all_star= 'Playoffs')
shaquille_oneal = playergamelog.PlayerGameLog(player_id='2992', season = 'ALL', season_type_all_star= 'Playoffs')
kobe_brian = playergamelog.PlayerGameLog(player_id='977', season = 'ALL', season_type_all_star= 'Playoffs')
dwyane_wade = playergamelog.PlayerGameLog(player_id='2548', season = 'ALL', season_type_all_star= 'Playoffs')
lebron_james = playergamelog.PlayerGameLog(player_id='2544', season = 'ALL', season_type_all_star= 'Playoffs')
stephen_curry = playergamelog.PlayerGameLog(player_id='201939', season = 'ALL', season_type_all_star= 'Playoffs')
kevin_durant = playergamelog.PlayerGameLog(player_id='201142', season = 'ALL', season_type_all_star= 'Playoffs')
kawhi_leonard = playergamelog.PlayerGameLog(player_id='202695', season = 'ALL', season_type_all_star= 'Playoffs')

lebron_df = lebron_james.get_data_frames()

lebron_df
