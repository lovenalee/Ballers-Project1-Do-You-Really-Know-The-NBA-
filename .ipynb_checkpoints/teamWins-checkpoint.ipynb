# %% [markdown]
# #### Which traditional stat is most important?
# * Data Needed: Player name, points, assists, rebounds, FG%, team margin
#
# * Find correlation between winning and an imputed stats (points, assists, rebounds, FG%).
#   Scatter Plot

# %%
# dependencies
import requests
import json
import os
import pandas as pd
import numpy as np

# %%
# consuming data file with years from 2014 and 2018
filepath = os.path.join('winloss_by_teams.csv')

tradStats_df = pd.read_csv(filepath)
tradStats_df.head()
# Out:
#                       TeamName League     Season          Division  \
# 0       NBAWashington Capitols    NBA  (1946-47)  Eastern Division
# 1     NBAGolden State Warriors    NBA  (1946-47)  Eastern Division
# 2           NBANew York Knicks    NBA  (1946-47)  Eastern Division
# 3  NBAProvidence Steam Rollers    NBA  (1946-47)  Eastern Division
# 4            NBABoston Celtics    NBA  (1946-47)  Eastern Division
#
#                   Franchise Team   W   L       %
# 0       Washington Capitols  WAS  49  11  81.70%
# 1     Golden State Warriors  PHI  35  25  58.30%
# 2           New York Knicks  NYK  33  27  55.00%
# 3  Providence Steam Rollers  PRO  28  32  46.70%
# 4            Boston Celtics  BOS  22  38  36.70%

# %% [markdown]
# ### Data Cleansing and Checks

# %%
# check all columns and names
tradStats_df.columns
# Out:
# Index(['TeamName', 'League', 'Season', 'Division', 'Franchise', 'Team', 'W',
#        'L', '%'],
#       dtype='object')

# %%
tradStats_removed = tradStats_df.replace({'NBA':''}, regex=True)
tradStats_removed
# Out:
#                       TeamName League     Season            Division  \
# 0          Washington Capitols         (1946-47)    Eastern Division
# 1        Golden State Warriors         (1946-47)    Eastern Division
# 2              New York Knicks         (1946-47)    Eastern Division
# 3     Providence Steam Rollers         (1946-47)    Eastern Division
# 4               Boston Celtics         (1946-47)    Eastern Division
# ...                        ...    ...        ...                 ...
# 1539           Houston Rockets         (2019-20)  Southwest Division
# 1540          Dallas Mavericks         (2019-20)  Southwest Division
# 1541         Memphis Grizzlies         (2019-20)  Southwest Division
# 1542         San Antonio Spurs         (2019-20)  Southwest Division
# 1543      New Orleans Pelicans         (2019-20)  Southwest Division
#
#                      Franchise Team   W   L       %
# 0          Washington Capitols  WAS  49  11  81.70%
# 1        Golden State Warriors  PHI  35  25  58.30%
# 2              New York Knicks  NYK  33  27  55.00%
# 3     Providence Steam Rollers  PRO  28  32  46.70%
# 4               Boston Celtics  BOS  22  38  36.70%
# ...                        ...  ...  ..  ..     ...
# 1539           Houston Rockets  HOU  44  28  61.10%
# 1540          Dallas Mavericks  DAL  43  32  57.30%
# 1541         Memphis Grizzlies  MEM  34  39  46.60%
# 1542         San Antonio Spurs  SAS  32  39  45.10%
# 1543      New Orleans Pelicans  NOP  30  42  41.70%
#
# [1544 rows x 9 columns]

# %%
tradStats_clean = tradStats_removed.loc[(tradStats_removed['Season'] >= '(2014-15)') & (tradStats_removed['Season'] <= '(2018-19)'),:]
tradStats_clean.head()
# Out:
#                 TeamName League     Season           Division  \
# 1364     Toronto Raptors         (2014-15)  Atlantic Division
# 1365      Boston Celtics         (2014-15)  Atlantic Division
# 1366       Brooklyn Nets         (2014-15)  Atlantic Division
# 1367  Philadelphia 76ers         (2014-15)  Atlantic Division
# 1368     New York Knicks         (2014-15)  Atlantic Division
#
#                Franchise Team   W   L       %
# 1364     Toronto Raptors  TOR  49  33  59.80%
# 1365      Boston Celtics  BOS  40  42  48.80%
# 1366       Brooklyn Nets  BRO  38  44  46.30%
# 1367  Philadelphia 76ers  PHI  18  64  22.00%
# 1368     New York Knicks  NYK  17  65  20.70%

# %%
# checking data counts
tradStats_clean.count()
# Out:
# TeamName     150
# League       150
# Season       150
# Division     150
# Franchise    150
# Team         150
# W            150
# L            150
# %            150
# dtype: int64

# %%
# check NaN values before replacing it with 0
tradStats_clean.isnull().values.any()
# Out:
# False

# %%
tradStats_clean.reset_index(drop=True)
# Out:
#                  TeamName League     Season            Division  \
# 0         Toronto Raptors         (2014-15)   Atlantic Division
# 1          Boston Celtics         (2014-15)   Atlantic Division
# 2           Brooklyn Nets         (2014-15)   Atlantic Division
# 3      Philadelphia 76ers         (2014-15)   Atlantic Division
# 4         New York Knicks         (2014-15)   Atlantic Division
# ..                    ...    ...        ...                 ...
# 145       Houston Rockets         (2018-19)  Southwest Division
# 146     San Antonio Spurs         (2018-19)  Southwest Division
# 147     Memphis Grizzlies         (2018-19)  Southwest Division
# 148  New Orleans Pelicans         (2018-19)  Southwest Division
# 149      Dallas Mavericks         (2018-19)  Southwest Division
#
#                 Franchise Team   W   L       %
# 0         Toronto Raptors  TOR  49  33  59.80%
# 1          Boston Celtics  BOS  40  42  48.80%
# 2           Brooklyn Nets  BRO  38  44  46.30%
# 3      Philadelphia 76ers  PHI  18  64  22.00%
# 4         New York Knicks  NYK  17  65  20.70%
# ..                    ...  ...  ..  ..     ...
# 145       Houston Rockets  HOU  53  29  64.60%
# 146     San Antonio Spurs  SAS  48  34  58.50%
# 147     Memphis Grizzlies  MEM  33  49  40.20%
# 148  New Orleans Pelicans  NOP  33  49  40.20%
# 149      Dallas Mavericks  DAL  33  49  40.20%
#
# [150 rows x 9 columns]

# %%
# saving output
#tradStats_df.to_csv("output/traditional_stats_clean2.csv", encoding="utf-8", index=True, header=True)
