# %%
# dependencies
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as sts

# %%
# filepathp = os.path.join('output','team_points.csv')
# filepathw = os.path.join('output','team_wins.csv')
teamPoints = pd.read_csv('output/team_points.csv')
teamWins = pd.read_csv('output/team_wins.csv')

# %%
merged_df = pd.merge(teamPoints,teamWins, on=['Team','Year'],how='outer')
merged_df
# Out:
#     Team  Year WINorLOSS  TeamPoints  Assists  FieldGoals  TotalRebounds  \
# 0    ATL  2014         W        2360      590         859            962
# 1    ATL  2015         W        6185     1566        2301           2392
# 2    ATL  2016         W        4763     1200        1795           1977
# 3    ATL  2017         W        4024      947        1498           1670
# 4    ATL  2018         W        1468      357         552            629
# ..   ...   ...       ...         ...      ...         ...            ...
# 145  WAS  2014         W        2273      583         897            959
# 146  WAS  2015         W        3973      969        1528           1702
# 147  WAS  2016         W        4708     1123        1807           1872
# 148  WAS  2017         W        6070     1344        2294           2416
# 149  WAS  2018         W        2516      662         954            960
#
#                TeamName  League     Season            Division  \
# 0         Atlanta Hawks     NaN  (2014-15)  Southeast Division
# 1         Atlanta Hawks     NaN  (2015-16)  Southeast Division
# 2         Atlanta Hawks     NaN  (2016-17)  Southeast Division
# 3         Atlanta Hawks     NaN  (2017-18)  Southeast Division
# 4         Atlanta Hawks     NaN  (2018-19)  Southeast Division
# ..                  ...     ...        ...                 ...
# 145  Washington Wizards     NaN  (2014-15)  Southeast Division
# 146  Washington Wizards     NaN  (2015-16)  Southeast Division
# 147  Washington Wizards     NaN  (2016-17)  Southeast Division
# 148  Washington Wizards     NaN  (2017-18)  Southeast Division
# 149  Washington Wizards     NaN  (2018-19)  Southeast Division
#
#               Franchise   W   L       %
# 0         Atlanta Hawks  60  22  73.20%
# 1         Atlanta Hawks  48  34  58.50%
# 2         Atlanta Hawks  43  39  52.40%
# 3         Atlanta Hawks  24  58  29.30%
# 4         Atlanta Hawks  29  53  35.40%
# ..                  ...  ..  ..     ...
# 145  Washington Wizards  46  36  56.10%
# 146  Washington Wizards  41  41  50.00%
# 147  Washington Wizards  49  33  59.80%
# 148  Washington Wizards  43  39  52.40%
# 149  Washington Wizards  32  50  39.00%
#
# [150 rows x 15 columns]

# %%
#merged_df.to_csv("output/merged_df.csv", encoding="utf-8", index=False, header=True)

# %%
merged_reduced_df = merged_df.loc[:,['Team','W','TeamPoints','Assists','FieldGoals','TotalRebounds']]
merged_reduced_df
# Out:
#     Team   W  TeamPoints  Assists  FieldGoals  TotalRebounds
# 0    ATL  60        2360      590         859            962
# 1    ATL  48        6185     1566        2301           2392
# 2    ATL  43        4763     1200        1795           1977
# 3    ATL  24        4024      947        1498           1670
# 4    ATL  29        1468      357         552            629
# ..   ...  ..         ...      ...         ...            ...
# 145  WAS  46        2273      583         897            959
# 146  WAS  41        3973      969        1528           1702
# 147  WAS  49        4708     1123        1807           1872
# 148  WAS  43        6070     1344        2294           2416
# 149  WAS  32        2516      662         954            960
#
# [150 rows x 6 columns]

# %%
merged_grp_teams = merged_reduced_df.groupby('Team')['W','TeamPoints','Assists','FieldGoals','TotalRebounds'].sum().reset_index()
# Out:
# <ipython-input-27-658d23ebefc1>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   merged_grp_teams = merged_reduced_df.groupby('Team')['W','TeamPoints','Assists','FieldGoals','TotalRebounds'].sum().reset_index()

# %%
traditional_stats = merged_grp_teams.rename(columns={'Team': 'Teams', 
                                                     'W': 'Wins', 
                                                     'TeamPoints': 'Points', 
                                                     'Assists': 'Assists', 
                                                     'FieldGoals': 'Field Goals', 
                                                     'TotalRebounds': 'Rebounds'})
traditional_stats
# Out:
#    Teams  Wins  Points  Assists  Field Goals  Rebounds
# 0    ATL   204   18800     4660         7005      7630
# 1    BOS   245   21072     4907         7798      8881
# 2    BRK   149   11696     2538         4325      4877
# 3    CHI   182   17120     3821         6349      7594
# 4    CHO   192   16715     3562         6070      7136
# 5    CLE   230   23684     5124         8643      9381
# 6    DAL   182   16043     3484         5946      6354
# 7    DEN   203   16817     3832         6212      6827
# 8    DET   193   16533     3470         6254      7232
# 9    GSW   322   30899     7959        11526     12030
# 10   HOU   270   24611     5107         8604      9838
# 11   IND   221   18460     3966         6950      7755
# 12   LAC   250   22399     4896         8178      8963
# 13   LAL   136   10922     2329         4085      4681
# 14   MEM   195   16868     3616         6229      7014
# 15   MIA   209   17928     3823         6747      7520
# 16   MIL   220   16998     3980         6428      6769
# 17   MIN   159   13704     3025         5063      5385
# 18   NOP   190   17486     3993         6609      7098
# 19   NYK   126   11707     2544         4414      5016
# 20   OKC   244   21872     4490         8149      9416
# 21   ORL   156   12291     2723         4668      5066
# 22   PHI   159   11730     2872         4333      5106
# 23   PHO   126   11746     2314         4357      5031
# 24   POR   238   20255     4071         7504      8644
# 25   SAC   160   13070     2813         4860      5397
# 26   SAS   278   24564     5723         9313     10223
# 27   TOR   273   23422     4629         8528      9530
# 28   UTA   227   18478     3834         6786      8015
# 29   WAS   211   19540     4681         7480      7909

# %%
# Calculate the correlation coefficient and linear regression model 
correlation_coefficient = round(sts.pearsonr(traditional_stats['Wins'], traditional_stats['Points'])[0],4)

print(f'The correlation coefficient for team wins to team points is: {correlation_coefficient}\n')

(slope, intercept, rvalue, pvalue, stderr) = sts.linregress(traditional_stats['Wins'], traditional_stats['Points'])
regress_values = slope * traditional_stats['Wins'] + intercept
#print(regress_values)

equation = 'y = ' + str(round(slope, 2)) + 'x + ' + str(round(intercept, 2))
print(f'the regression equation is: {equation}\n')
print(f'the r value is: {rvalue}\n')
plt.figure(figsize=(15,8))
plt.scatter(traditional_stats['Wins'], traditional_stats['Points'], s=10, c='b')
plt.plot(traditional_stats['Wins'], regress_values, color='red')
plt.title('Wins to Points',fontsize =15)
plt.xlabel('Wins',fontsize =14)
plt.ylabel('Points',fontsize =15)
plt.annotate(equation, xy=(90,10), fontsize=10, color='red')
plt.show()
# Out:
# The correlation coefficient for team wins to team points is: 0.9684
#
# the regression equation is: y = 96.68x + -1904.59
#
# the r value is: 0.9684242337446404
