# %%
import requests
import json
import os
import pandas as pd

# %% [markdown]
# #### Which traditional stat is most important?
# * Data Needed: Player name, points, assists, rebounds, FG%, team margin
#
# * Find correlation between winning and an imputed stats (points, assists, rebounds, FG%).
#   Scatter Plot

# %%
filepath = os.path.join('NBA_Season_Data.csv')

tradStats_df = pd.read_csv(filepath)
tradStats_df
# Out:
#        Year   Tm          Player  Age   G    MP   PER    TS%  3PAr    FTr  \
# 0      1978  NOJ  Truck Robinson   26  82  3638  15.7  0.481   NaN  0.340
# 1      1978  BUF     Randy Smith   29  82  3314  19.1  0.521   NaN  0.326
# 2      1978  WSB     Elvin Hayes   32  81  3246  17.1  0.489   NaN  0.365
# 3      1978  BOS     Dave Cowens   29  77  3215  18.6  0.533   NaN  0.233
# 4      1978  NYK      Bob McAdoo   26  79  3182  22.0  0.567   NaN  0.412
# ...     ...  ...             ...  ...  ..   ...   ...    ...   ...    ...
# 17724  2016  BRK               0    0   0     0   0.0  0.000   0.0  0.000
# 17725  2016  BRK               0    0   0     0   0.0  0.000   0.0  0.000
# 17726  2016  BRK               0    0   0     0   0.0  0.000   0.0  0.000
# 17727  2016  BRK               0    0   0     0   0.0  0.000   0.0  0.000
# 17728  2016  BRK               0    0   0     0   0.0  0.000   0.0  0.000
#
#        ...  D-WORP  Adjusted WORP  Estimated Position  BBRef Pos  \
# 0      ...     1.1            1.1                 3.6        4.0
# 1      ...    -2.3            7.4                 1.0        2.0
# 2      ...     3.4            6.5                 4.2        4.0
# 3      ...     6.1           12.5                 3.9        5.0
# 4      ...     2.6           10.6                 3.6        5.0
# ...    ...     ...            ...                 ...        ...
# 17724  ...     0.0            NaN                 0.0        NaN
# 17725  ...     0.0            NaN                 0.0        NaN
# 17726  ...     0.0            NaN                 0.0        NaN
# 17727  ...     0.0            NaN                 0.0        NaN
# 17728  ...     0.0            NaN                 0.0        NaN
#
#        Age on Feb 1  Yrs Experience  Height  Weight  Rounded Position  \
# 0             26.33             3.0    79.0   225.0               4.0
# 1             29.14             6.0    75.0   180.0               1.0
# 2             32.21             9.0    81.0   235.0               4.0
# 3             29.27             7.0    81.0   230.0               4.0
# 4             26.36             5.0    81.0   210.0               4.0
# ...             ...             ...     ...     ...               ...
# 17724           NaN             NaN     NaN     NaN               0.0
# 17725           NaN             NaN     NaN     NaN               0.0
# 17726           NaN             NaN     NaN     NaN               0.0
# 17727           NaN             NaN     NaN     NaN               0.0
# 17728           NaN             NaN     NaN     NaN               0.0
#
#        Rounded Age
# 0             26.0
# 1             29.0
# 2             32.0
# 3             29.0
# 4             26.0
# ...            ...
# 17724          NaN
# 17725          NaN
# 17726          NaN
# 17727          NaN
# 17728          NaN
#
# [17729 rows x 109 columns]
